# %% [markdown]
# <a href="https://colab.research.google.com/github/qkjquiming-sketch/CPE009A-CPE12S2-OOP1/blob/main/Midterm_Exam_in_OOP_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def isBalanced():
    if input == '({[]}), ([)], ((())), ({)}':
        print('Balanced')
    else:
        print('Not balanced')

# Main
input = input('Enter string: ')
isBalanced()

# Hindi ko na po alam hehehe
# Out:
# Enter string: ()
# Not balanced
